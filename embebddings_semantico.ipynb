# %% [markdown]
# <a href="https://colab.research.google.com/github/GAYARRI/text-classifier/blob/master/embebddings_semantico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  # !pip install -U sentence-transformers                                # importamos modulo para trabajar con excel y el grupo de modelos pre-entrenados
                                                                     # porque no están en la configuarcion de Google Colab por defecto.                                                            # Actualizamos tambien a la última versión de Numpy
# !pip install openpyxl
# !pip install sentence_transformers
# !pip install numpy==1.22.0

# %%
from sentence_transformers import SentenceTransformer,util            # cargamos los modulos a utilizar de Modelos pre-entrenados y el módulo útil para trabajar con oraciones completas
                                                                      # cargamos la bibioteca pandas
import pandas as pd

# %%
                                                                       # cargamos el modulo de trabajo con openpyxl para importar el archivo de entrada
                                                                       # 'ChatGPT.xlsx'. Si lo hicieramos con su equivalente xls a veces da da error en algunas ocasiones.
                                                                       # No hay problema porque solo lo utilizamos para cargar la actividad a partir de la cual
                                                                       # vamos a recomendar las 10 restantes.Podemos utilizar el que más convenga
                                                                       # El resto de líneas son para respetar ese formato de llamada al api.

from openpyxl import load_workbook

workbook = load_workbook('ChatGPT.xlsx')                               # hay que cargarlo solamente cada vez que se cambie la transparencia de entrada
hoja = workbook['Results']
valor = hoja['A1'].value
print(valor)

from openpyxl import load_workbook

workbook = load_workbook('Etiquetas_Historia.xlsx')                               # hay que cargarlo solamente cada vez que se cambie la transparencia de entrada
hoja2 = workbook['Base']
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-214289e1812a> in <cell line: 9>()
#       7 from openpyxl import load_workbook
#       8
# ----> 9 workbook = load_workbook('ChatGPT.xlsx')                               # hay que cargarlo solamente cada vez que se cambie la transparencia de entrada
#      10 hoja = workbook['Results']
#      11 valor = hoja['A1'].value
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     342
#     343     """
# --> 344     reader = ExcelReader(filename, read_only, keep_vba,
#     345                          data_only, keep_links, rich_text)
#     346     reader.read()
#
# /usr/local/lib/python3.10/dist-packages/openpyxl/reader/excel.py in __init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
# ...

# %%
df=pd.read_excel('Etiquetas_Historia.xlsx')                                                   # Igualmemnte cargamos el archivo con el total de transparencias.
                                                                          # En este caso se trata de todo
                                                                          # De nuevo si da probemas con la extension xlsx , se hace una copia con la extension
                                                                          # xlsx . Este solo se carga al inicio de sesion, después basta con cargar el ChatGPT si
                                                                          # se cambia el imput, pero este que tarda mas ya no hace falta , minetras nos aparexc en
                                                                          # el menú de archivos de la izquierda.
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-12-ba0ddae22db9> in <cell line: 1>()
# ----> 1 df=pd.read_excel('Etiquetas_Historia.xlsx')                                                   # Igualmemnte cargamos el archivo con el total de transparencias.
#       2                                                                           # En este caso se trata de todo
#       3                                                                           # De nuevo si da probemas con la extension xlsx , se hace una copia con la extension
#       4                                                                           # xlsx . Este solo se carga al inicio de sesion, después basta con cargar el ChatGPT si
# ...

# %%
Total=df.loc[:9214,['idtransparencia','Lista']]                          # Cargamos el dataframe Total con las features 'idtransparencia y 'Lista' que no es más que
print(Total)                                                             # una concatenacion de las 10 etiquetas de cada transparecia . El proximo paso es hacer esa
                                                                         # concatenacion desde el codigo de este Notebook. De hecho tenemos una versión que funcionaba
                                                                         # correctamente con ese plantemiento pero empezo a dar error y lo cambiamos.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-3fa735fed9a9> in <cell line: 1>()
# ----> 1 Total=df.loc[:9214,['idtransparencia','Lista']]                          # Cargamos el dataframe Total con las features 'idtransparencia y 'Lista' que no es más que
#       2 print(Total)                                                             # una concatenacion de las 10 etiquetas de cada transparecia . El proximo paso es hacer esa
#       3                                                                          # concatenacion desde el codigo de este Notebook. De hecho tenemos una versión que funcionaba
#       4                                                                          # correctamente con ese plantemiento pero empezo a dar error y lo cambiamos.
#
# NameError: name 'df' is not defined

# %%
from sentence_transformers import SentenceTransformer,util                      # cargamos la versión de los modelos pre-entrenados y el comado 'util' para operar con tranformers
model = SentenceTransformer('all-mpnet-base-v2')                                # elegimos el modelo de trabajo , que teóricamente es el de más precisión
                                                                                # aunque también es el que más tarda.

# %%
entrada_embedding=model.encode([valor])    #### Esto se ejecuta con cada cambio de la transparcia de entrada y por tanto cada vez que cargamos el archivo
                                           #### de imputs ChatGPT.xlsx . Se trata de codificar el imput de entrada con el modelo de embedding.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-5c0b66ff32d5> in <cell line: 1>()
# ----> 1 entrada_embedding=model.encode([valor])    #### Esto se ejecuta con cada cambio de la transparcia de entrada y por tanto cada vez que cargamos el archivo
#       2                                            #### de imputs ChatGPT.xlsx . Se trata de codificar el imput de entrada con el modelo de embedding.
#       3
#       4
#
# NameError: name 'model' is not defined

# %%
embeddings=model.encode(Total['Lista'])     ####  Con este model y este universo de Editex tarda alrededor de 5 min. Codifica todos el universo de slides que se quiere
                                            ####  utilizar como referencia ó alternativa al imput elegido.

# %%
import torch
import numpy


import pandas as pd






similitudes = util.pytorch_cos_sim(entrada_embedding,embeddings)   # cálculo de las similitudes entre el imput y el universo disponible
keys= similitudes.argsort(descending=True)                         # Lista ordenada de similitdes del vector input y el universo.
indices=keys.squeeze().tolist()                            # Nos quedamos solo con los indices y seleccionamos los 10 más parecidos.


df = pd.DataFrame(indices,keys)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-9b8a2020fa26> in <cell line: 12>()
#      10
#      11
# ---> 12 similitudes = util.pytorch_cos_sim(entrada_embedding,embeddings)   # cálculo de las similitudes entre el imput y el universo disponible
#      13 keys= similitudes.argsort(descending=True)                         # Lista ordenada de similitdes del vector input y el universo.
#      14 indices=keys.squeeze().tolist()                            # Nos quedamos solo con los indices y seleccionamos los 10 más parecidos.
#
# NameError: name 'entrada_embedding' is not defined

# %%
import pandas as pd
from openpyxl import load_workbook                                       # Hacemos el camino de vuelta y sacamos una visualizacion en excel de loc campos
                                                                         # 'idtransparencia' y 'Lista' ( concatenacion de etiquetas)
                                                                         # al descargarla saca una copia del ChatGPT.xlsx inicial

ruta_archivo_existente = '/content/ChatGPT.xlsx'
book = load_workbook(ruta_archivo_existente)
writer = pd.ExcelWriter(ruta_archivo_existente, engine='openpyxl')
writer.book = book

sheet_name = 'Results'  # Nombre de la hoja existente en la que deseas escribir
startrow = 5  # Fila de inicio para pegar los datos del DataFrame
startcol = 1  # Columna de inicio para pegar los datos del DataFrame

escogido.to_excel(writer, sheet_name=sheet_name, index=True, startrow=startrow, startcol=startcol)
writer.save()
# Out:
# <ipython-input-56-0021fc6aa7b3>:9: FutureWarning: Setting the `book` attribute is not part of the public API, usage can give unexpected or corrupted results and will be removed in a future version
#   writer.book = book
# <ipython-input-56-0021fc6aa7b3>:16: FutureWarning: save is not part of the public API, usage can give unexpected results and will be removed in a future version
#   writer.save()
